# %%
import pandas as pd

# %%
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

df = pd.DataFrame(data)

print(df[['Name', 'Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
df[df.columns[1:4]]
# Out:
#    Age    Address Qualification
# 0   27      Delhi           Msc
# 1   24     Kanpur            MA
# 2   22  Allahabad           MCA
# 3   32    Kannauj           Phd

# %%
df.loc[1:3,['Name','Qualification']]
# Out:
#      Name Qualification
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
df.loc[0:1,'Name':'Address']
# Out:
#      Name  Age Address
# 0     Jai   27   Delhi
# 1  Princi   24  Kanpur

# %%
#selecting row 1 of all columns

df.loc[0,:]
# Out:
# Name               Jai
# Age                 27
# Address          Delhi
# Qualification      Msc
# Name: 0, dtype: object

# %%
df.iloc[:,0:2]
# Out:
#      Name  Age
# 0     Jai   27
# 1  Princi   24
# 2  Gaurav   22
# 3    Anuj   32

# %%
df.iloc[0:2, 1:3]
# Out:
#    Age Address
# 0   27   Delhi
# 1   24  Kanpur

# %%
address = ['Delhi','Bangalore', 'Chennai', 'Patna']
df['Address'] = address

df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24  Bangalore            MA
# 2  Gaurav   22    Chennai           MCA
# 3    Anuj   32      Patna           Phd

# %%
df.insert(2,"Height",[5.1, 6.2, 5.1, 5.2], allow_duplicates=True)
df
# Out:
#      Name  Age  Height    Address Qualification
# 0     Jai   27     5.1      Delhi           Msc
# 1  Princi   24     6.2  Bangalore            MA
# 2  Gaurav   22     5.1    Chennai           MCA
# 3    Anuj   32     5.2      Patna           Phd

# %%
df2 = df.assign(address2 = ['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'] )
df2
# Out:
#      Name  Age  Height    Address Qualification   address2
# 0     Jai   27     5.1      Delhi           Msc      Delhi
# 1  Princi   24     6.2  Bangalore            MA     Kanpur
# 2  Gaurav   22     5.1    Chennai           MCA  Allahabad
# 3    Anuj   32     5.2      Patna           Phd    Kannauj

# %%
df2.drop(['address2'],axis=1, inplace=True)
df2
# Out:
#      Name  Age  Height    Address Qualification
# 0     Jai   27     5.1      Delhi           Msc
# 1  Princi   24     6.2  Bangalore            MA
# 2  Gaurav   22     5.1    Chennai           MCA
# 3    Anuj   32     5.2      Patna           Phd

# %%
data = pd.read_csv('nba.csv', index_col='Name')
data.drop(['Team', 'Weight'], axis=1, inplace=True)

data.head()
# Out:
#                Number Position   Age Height            College     Salary
# Name
# Avery Bradley     0.0       PG  25.0    6-2              Texas  7730337.0
# Jae Crowder      99.0       SF  25.0    6-6          Marquette  6796117.0
# John Holland     30.0       SG  27.0    6-5  Boston University        NaN
# R.J. Hunter      28.0       SG  22.0    6-5      Georgia State  1148640.0
# Jonas Jerebko     8.0       PF  29.0   6-10                NaN  5000000.0

# %%
data.drop(['Avery Bradley', 'John Holland', 'R.J. Hunter'],inplace = True)
data
# Out:
#                Number Position   Age Height    College      Salary
# Name
# Jae Crowder      99.0       SF  25.0    6-6  Marquette   6796117.0
# Jonas Jerebko     8.0       PF  29.0   6-10        NaN   5000000.0
# Amir Johnson     90.0       PF  29.0    6-9        NaN  12000000.0
# Jordan Mickey    55.0       PF  21.0    6-8        LSU   1170960.0
# Kelly Olynyk     41.0        C  25.0    7-0    Gonzaga   2165160.0
# ...               ...      ...   ...    ...        ...         ...
# Shelvin Mack      8.0       PG  26.0    6-3     Butler   2433333.0
# Raul Neto        25.0       PG  24.0    6-1        NaN    900000.0
# Tibor Pleiss     21.0        C  26.0    7-3        NaN   2900000.0
# Jeff Withey      24.0        C  26.0    7-0     Kansas    947276.0
# NaN               NaN      NaN   NaN    NaN        NaN         NaN
#
# [455 rows x 6 columns]

# %%
data = pd.read_csv('nba.csv', index_col='Name')

first = data.loc['Avery Bradley']
second = data.loc['R.J. Hunter']

print(first, "\n\n\n", second)data = pd.read_csv('nba.csv', index_col='Name')
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
df = pd.read_csv('nba.csv')
new_row = pd.DataFrame(
    {
        'Name':'Geeks', 
        'Team':'Boston', 
        'Number':3,
        'Position':'PG', 
        'Age':33, 
        'Height':'6-2',
        'Weight':189, 
        'College':'MIT', 
        'Salary':99999},
    index =[0]
)

df = pd.concat([new_row,df]).reset_index(drop = True)

# %%
df
# Out:
#       Name            Team  Number Position   Age Height  Weight  \
# 0    Geeks          Boston     3.0       PG  33.0    6-2   189.0
# 1      NaN  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2      NaN  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      NaN  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4      NaN  Boston Celtics    28.0       SG  22.0    6-5   185.0
# ..     ...             ...     ...      ...   ...    ...     ...
# 454    NaN       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455    NaN       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 456    NaN       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457    NaN       Utah Jazz    24.0        C  26.0    7-0   231.0
# 458    NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                  MIT    99999.0
# 1                Texas  7730337.0
# 2            Marquette  6796117.0
# 3    Boston University        NaN
# ...

# %%
data_top = data.head()
data_top
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
for col in data.columns:
    print(col)
# Out:
# Team
# Number
# Position
# Age
# Height
# Weight
# College
# Salary

# %%
list(data.columns)
# Out:
# ['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
(data.columns.values)
# Out:
# array(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#        'Salary'], dtype=object)

# %%
data.columns.values.tolist()
# Out:
# ['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
sorted(data)
# Out:
# ['Age', 'College', 'Height', 'Number', 'Position', 'Salary', 'Team', 'Weight']
